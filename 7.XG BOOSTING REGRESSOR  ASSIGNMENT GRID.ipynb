# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
param_grid ={'loss':[ 'huber', 'quantile'],
            'n_estimators':[100,500,1000,1500],
         'criterion':['friedman_mse', 'mse']}

grid=GridSearchCV(GradientBoostingRegressor(),param_grid, refit = True, verbose=3, n_jobs=-1)



grid.fit(independent,dependent)
# Out:
# C:\Users\MANIKA\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:   42.8s finished
# C:\Users\MANIKA\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=GradientBoostingRegressor(alpha=0.9,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_no_change=None,
#                                                  presort='auto',
#                                                  random_state=None,
#                                                  subsample=1.0, tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'mse'],
#                          'loss': ['huber', 'quantile'],
#                          'n_estimators': [100, 500, 1000, 1500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'mse', 'loss': 'huber', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.352487      0.012434         0.010551        0.003595
# 1        1.548778      0.049852         0.013068        0.003623
# 2        3.514497      0.431805         0.019451        0.004068
# 3        7.395329      0.521524         0.036508        0.004762
# 4        0.387936      0.012496         0.011923        0.003139
# 5        1.655655      0.103202         0.016440        0.001133
# 6        3.130330      0.219575         0.022018        0.001763
# 7        4.948536      0.193994         0.027867        0.002829
# 8        0.528358      0.005260         0.004869        0.004138
# 9        2.635033      0.014920         0.020061        0.004691
# 10       5.147000      0.052580         0.026095        0.000794
# 11       7.753176      0.058578         0.035520        0.003043
# 12       0.391546      0.007499         0.008657        0.006908
# 13       1.726014      0.065723         0.021025        0.003869
# 14       3.165260      0.243072         0.020548        0.005129
# 15       4.217986      0.388251         0.024046        0.005880
#
#    param_criterion param_loss param_n_estimators  \
# 0     friedman_mse      huber                100
# 1     friedman_mse      huber                500
# 2     friedman_mse      huber               1000
# 3     friedman_mse      huber               1500
# 4     friedman_mse   quantile                100
# 5     friedman_mse   quantile                500
# 6     friedman_mse   quantile               1000
# 7     friedman_mse   quantile               1500
# 8              mse      huber                100
# 9              mse      huber                500
# 10             mse      huber               1000
# 11             mse      huber               1500
# 12             mse   quantile                100
# 13             mse   quantile                500
# 14             mse   quantile               1000
# 15             mse   quantile               1500
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'loss': 'huber',...           0.868085
# 1   {'criterion': 'friedman_mse', 'loss': 'huber',...           0.844823
# 2   {'criterion': 'friedman_mse', 'loss': 'huber',...           0.828608
# 3   {'criterion': 'friedman_mse', 'loss': 'huber',...           0.816207
# 4   {'criterion': 'friedman_mse', 'loss': 'quantil...           0.620111
# 5   {'criterion': 'friedman_mse', 'loss': 'quantil...           0.646826
# 6   {'criterion': 'friedman_mse', 'loss': 'quantil...           0.630111
# 7   {'criterion': 'friedman_mse', 'loss': 'quantil...           0.641939
# 8   {'criterion': 'mse', 'loss': 'huber', 'n_estim...           0.868166
# 9   {'criterion': 'mse', 'loss': 'huber', 'n_estim...           0.846168
# 10  {'criterion': 'mse', 'loss': 'huber', 'n_estim...           0.826024
# 11  {'criterion': 'mse', 'loss': 'huber', 'n_estim...           0.822810
# 12  {'criterion': 'mse', 'loss': 'quantile', 'n_es...           0.621414
# 13  {'criterion': 'mse', 'loss': 'quantile', 'n_es...           0.620545
# 14  {'criterion': 'mse', 'loss': 'quantile', 'n_es...           0.646048
# 15  {'criterion': 'mse', 'loss': 'quantile', 'n_es...           0.620533
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.855337           0.839135         0.854186        0.011847
# 1            0.841607           0.824795         0.837075        0.008782
# 2            0.829347           0.818922         0.825626        0.004750
# 3            0.804651           0.814090         0.811650        0.005023
# 4            0.547056           0.678276         0.615148        0.053685
# 5            0.548077           0.677902         0.624269        0.055349
# 6            0.548402           0.683136         0.620550        0.055419
# 7            0.547334           0.690391         0.626555        0.059407
# 8            0.855339           0.839177         0.854227        0.011861
# 9            0.841273           0.823375         0.836938        0.009797
# 10           0.828710           0.815559         0.823431        0.005673
# 11           0.803459           0.813109         0.813126        0.007900
# 12           0.547086           0.670568         0.613023        0.050759
# 13           0.548434           0.671970         0.613650        0.050668
# 14           0.548434           0.680672         0.625051        0.055990
# 15           0.548677           0.681440         0.616883        0.054262
#
#     rank_test_score
# 0                 2
# 1                 3
# 2                 5
# 3                 8
# 4                14
# 5                11
# 6                12
# 7                 9
# 8                 1
# 9                 4
# 10                6
# 11                7
# 12               16
# 13               15
# 14               10
# 15               13

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:30
# BMI:45
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[4984.87323953]
